# %%
import sys
sys.path.append("..") # Adds higher directory to python modules path.
from plottingFunctions import plotPredictions
from notebookFunctions import plotEpochAccuracyAndLoss, plotBatchAccuracyAndLoss

# %%
h = "/home/ubuntu/project/"
d = h + 'data/groundcover2016/test/'
unet_path = h + "model_checkpoints/unet/"

shape = (256,256)

# %%
plotBatchAccuracyAndLoss(unet_path + 'small_singleclass_regression_batch.csv')
