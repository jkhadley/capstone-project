# %%
from plottingFunctions import plotBatchMetrics
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
h = "/home/ubuntu/project/"
d = h + 'data/groundcover2016/test/'
unet_path = h + "model_checkpoints/unet/"
results_path = h + "results/"

shape = (256,256)

# %%
plotBatchMetrics(results_path + 'maize8Regression_batch.csv',32)

# %%
plotBatchMetrics(results_path + 'multiclass32Regression_batch.csv',32)

# %%
plotBatchMetrics(results_path + "maize32FullRegression_batch.csv",.128)
